# %% [markdown]
# DATA CLEANING AND PREPROCESSING

# %%
import pandas as pd

# Load the datasets
df_customers = df_customers = pd.read_csv(r'C:\Users\Administrator\Desktop\Customers.csv', encoding='latin-1')
df_Data_Dictionary = pd.read_csv(r'C:\Users\Administrator\Downloads\Data_Dictionary.csv', encoding='latin-1')
df_stores = pd.read_csv(r' C:\Users\Administrator\Desktop\Stores.csv', encoding='latin-1')
df_sales = pd.read_csv(r'C:\Users\Administrator\Desktop\Sales.csv', encoding='latin-1')
df_Products = pd.read_csv(r'C:\Users\Administrator\Desktop\Products.csv', encoding='latin-1')
df_exc_rates = pd.read_csv(r'C:\Users\Administrator\Downloads\Exchange_Rates.csv', encoding='latin-1')

# %%
import pandas as pd
# Load datasets

df_customers = pd.read_csv(r'C:\Users\Administrator\Desktop\Customers.csv',encoding='latin-1')
df_customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
df_customers.shape
# Out:
# (15266, 10)

# %%
df_customers.isnull()
# Out:
#        CustomerKey  Gender   Name   City  State Code  State  Zip Code  \
# 0            False   False  False  False       False  False     False
# 1            False   False  False  False       False  False     False
# 2            False   False  False  False       False  False     False
# 3            False   False  False  False       False  False     False
# 4            False   False  False  False       False  False     False
# ...            ...     ...    ...    ...         ...    ...       ...
# 15261        False   False  False  False       False  False     False
# 15262        False   False  False  False       False  False     False
# 15263        False   False  False  False       False  False     False
# 15264        False   False  False  False       False  False     False
# 15265        False   False  False  False       False  False     False
#
#        Country  Continent  Birthday
# 0        False      False     False
# 1        False      False     False
# ...

# %% [markdown]
# #To run a func.

# %%
df_customers.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
df_customers.isnull().sum().sum()# total sum of datasets
# Out:
# 10

# %% [markdown]
# ## filling the null values

# %%
df2_customers =  df.fillna(value = 0)# where there is null value zero will replace null value , df2 is wil not disturb the original dataset
df2_customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
#CHECK THE NULL VALUE IS REPLACING OPR NOT

# %%
df.isnull().sum().sum()
# Out:
# 10

# %%
df3_customers =  df.fillna(value = 5) #where there is null value 5 will replace 0 value , df3 is wil not disturb the original dataset
df3_customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
# filling null values with previous value

df4_customers = df.fillna(method ='pad')# null values fill by previous value row wise
df4_customers
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_12228\2340941636.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df4_customers = df.fillna(method ='pad')
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# ...

# %%
df4_customers.isnull().sum()
# Out:
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State Code     0
# State          0
# Zip Code       0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %% [markdown]
# # fill the null values with the next value

# %%
df5_customers = df.fillna(method = 'bfill') # bfill: backward fill
df5_customers
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_12228\29064270.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df5_customers = df.fillna(method = 'bfill') # bfill: backward fill
#              Table           Field  \
# 0            Sales    Order Number
# 1            Sales       Line Item
# 2            Sales      Order Date
# 3            Sales   Delivery Date
# 4            Sales     CustomerKey
# 5            Sales        StoreKey
# 6            Sales      ProductKey
# 7            Sales        Quantity
# 8            Sales   Currency Code
# 9        Customers     CustomerKey
# 10       Customers          Gender
# 11       Customers            Name
# 12       Customers            City
# 13       Customers      State Code
# 14       Customers           State
# 15       Customers        Zip Code
# 16       Customers         Country
# 17       Customers       Continent
# ...

# %%
df6_customers = df.fillna(method = 'pad',axis = 1)
df6_customers
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_12228\1016298646.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df6_customers = df.fillna(method = 'pad',axis = 1) # bfill: backward fill
#              Table           Field  \
# 0            Sales    Order Number
# 1            Sales       Line Item
# 2            Sales      Order Date
# 3            Sales   Delivery Date
# 4            Sales     CustomerKey
# 5            Sales        StoreKey
# 6            Sales      ProductKey
# 7            Sales        Quantity
# 8            Sales   Currency Code
# 9        Customers     CustomerKey
# 10       Customers          Gender
# 11       Customers            Name
# 12       Customers            City
# 13       Customers      State Code
# 14       Customers           State
# 15       Customers        Zip Code
# 16       Customers         Country
# 17       Customers       Continent
# ...

# %%
df7_customers = df.fillna(method = 'bfill',axis = 1)
df7_customers
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_12228\189590757.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df7_customers = df.fillna(method = 'bfill',axis = 1)
#              Table           Field  \
# 0            Sales    Order Number
# 1            Sales       Line Item
# 2            Sales      Order Date
# 3            Sales   Delivery Date
# 4            Sales     CustomerKey
# 5            Sales        StoreKey
# 6            Sales      ProductKey
# 7            Sales        Quantity
# 8            Sales   Currency Code
# 9        Customers     CustomerKey
# 10       Customers          Gender
# 11       Customers            Name
# 12       Customers            City
# 13       Customers      State Code
# 14       Customers           State
# 15       Customers        Zip Code
# 16       Customers         Country
# 17       Customers       Continent
# ...

# %%
df_customers = df.drop_duplicates()
df_customers
# Out:
#              Table           Field  \
# 0            Sales    Order Number
# 1            Sales       Line Item
# 2            Sales      Order Date
# 3            Sales   Delivery Date
# 4            Sales     CustomerKey
# 5            Sales        StoreKey
# 6            Sales      ProductKey
# 7            Sales        Quantity
# 8            Sales   Currency Code
# 9        Customers     CustomerKey
# 10       Customers          Gender
# 11       Customers            Name
# 12       Customers            City
# 13       Customers      State Code
# 14       Customers           State
# 15       Customers        Zip Code
# 16       Customers         Country
# 17       Customers       Continent
# 18       Customers        Birthday
# 19        Products      ProductKey
# 20        Products    Product Name
# 21        Products           Brand
# 22        Products           Color
# 23        Products   Unit Cost USD
# 24        Products  Unit Price USD
# ...

# %%
df_customers = df.drop(columns = "Description")
df_customers
# Out:
#              Table           Field
# 0            Sales    Order Number
# 1            Sales       Line Item
# 2            Sales      Order Date
# 3            Sales   Delivery Date
# 4            Sales     CustomerKey
# 5            Sales        StoreKey
# 6            Sales      ProductKey
# 7            Sales        Quantity
# 8            Sales   Currency Code
# 9        Customers     CustomerKey
# 10       Customers          Gender
# 11       Customers            Name
# 12       Customers            City
# 13       Customers      State Code
# 14       Customers           State
# 15       Customers        Zip Code
# 16       Customers         Country
# 17       Customers       Continent
# 18       Customers        Birthday
# 19        Products      ProductKey
# 20        Products    Product Name
# 21        Products           Brand
# 22        Products           Color
# 23        Products   Unit Cost USD
# 24        Products  Unit Price USD
# 25        Products  SubcategoryKey
# ...

# %% [markdown]
# # Replacing spaces in column name

# %%
df_customers["Table"].str.strip()
# Out:
# 0              Sales
# 1              Sales
# 2              Sales
# 3              Sales
# 4              Sales
# 5              Sales
# 6              Sales
# 7              Sales
# 8              Sales
# 9          Customers
# 10         Customers
# 11         Customers
# 12         Customers
# 13         Customers
# 14         Customers
# 15         Customers
# 16         Customers
# 17         Customers
# 18         Customers
# 19          Products
# 20          Products
# 21          Products
# 22          Products
# 23          Products
# 24          Products
# 25          Products
# 26          Products
# 27          Products
# 28          Products
# 29            Stores
# 30            Stores
# 31            Stores
# 32            Stores
# 33            Stores
# 34    Exchange Rates
# 35    Exchange Rates
# 36    Exchange Rates
# Name: Table, dtype: object

# %%
df_customers["Table"].str.lstrip("...")
# Out:
# 0              Sales
# 1              Sales
# 2              Sales
# 3              Sales
# 4              Sales
# 5              Sales
# 6              Sales
# 7              Sales
# 8              Sales
# 9          Customers
# 10         Customers
# 11         Customers
# 12         Customers
# 13         Customers
# 14         Customers
# 15         Customers
# 16         Customers
# 17         Customers
# 18         Customers
# 19          Products
# 20          Products
# 21          Products
# 22          Products
# 23          Products
# 24          Products
# 25          Products
# 26          Products
# 27          Products
# 28          Products
# 29            Stores
# 30            Stores
# 31            Stores
# 32            Stores
# 33            Stores
# 34    Exchange Rates
# 35    Exchange Rates
# 36    Exchange Rates
# Name: Table, dtype: object

# %%
df_customers["Table"].str.lstrip(["/","..."])
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# Name: Table, dtype: float64

# %%
df_customers["Table"] = df["Table"].str.lstrip("...")
df_customers
# Out:
#              Table           Field
# 0            Sales    Order Number
# 1            Sales       Line Item
# 2            Sales      Order Date
# 3            Sales   Delivery Date
# 4            Sales     CustomerKey
# 5            Sales        StoreKey
# 6            Sales      ProductKey
# 7            Sales        Quantity
# 8            Sales   Currency Code
# 9        Customers     CustomerKey
# 10       Customers          Gender
# 11       Customers            Name
# 12       Customers            City
# 13       Customers      State Code
# 14       Customers           State
# 15       Customers        Zip Code
# 16       Customers         Country
# 17       Customers       Continent
# 18       Customers        Birthday
# 19        Products      ProductKey
# 20        Products    Product Name
# 21        Products           Brand
# 22        Products           Color
# 23        Products   Unit Cost USD
# 24        Products  Unit Price USD
# 25        Products  SubcategoryKey
# ...

# %%
df_customers["Table"].str.replace('[^a-zA-Z0-9]','')
# Out:
# 0              Sales
# 1              Sales
# 2              Sales
# 3              Sales
# 4              Sales
# 5              Sales
# 6              Sales
# 7              Sales
# 8              Sales
# 9          Customers
# 10         Customers
# 11         Customers
# 12         Customers
# 13         Customers
# 14         Customers
# 15         Customers
# 16         Customers
# 17         Customers
# 18         Customers
# 19          Products
# 20          Products
# 21          Products
# 22          Products
# 23          Products
# 24          Products
# 25          Products
# 26          Products
# 27          Products
# 28          Products
# 29            Stores
# 30            Stores
# 31            Stores
# 32            Stores
# 33            Stores
# 34    Exchange Rates
# 35    Exchange Rates
# 36    Exchange Rates
# Name: Table, dtype: object

# %%
df_customers["Table"].str.replace('[^a-zA-Z0-9]','')
df
# Out:
#              Table           Field  \
# 0            Sales    Order Number
# 1            Sales       Line Item
# 2            Sales      Order Date
# 3            Sales   Delivery Date
# 4            Sales     CustomerKey
# 5            Sales        StoreKey
# 6            Sales      ProductKey
# 7            Sales        Quantity
# 8            Sales   Currency Code
# 9        Customers     CustomerKey
# 10       Customers          Gender
# 11       Customers            Name
# 12       Customers            City
# 13       Customers      State Code
# 14       Customers           State
# 15       Customers        Zip Code
# 16       Customers         Country
# 17       Customers       Continent
# 18       Customers        Birthday
# 19        Products      ProductKey
# 20        Products    Product Name
# 21        Products           Brand
# 22        Products           Color
# 23        Products   Unit Cost USD
# 24        Products  Unit Price USD
# ...

# %% [markdown]
# #Apply Lamda function

# %%
#df_customers["Table"] = df_customers["Table"].str.replace('[^a-zA-Z0-9]','')

df_customers["Table"].apply(lambda x: x[0:3] + '-' + x [3:6] + '-' + x[6:10])
# Out:
# 0          Sal-es-
# 1          Sal-es-
# 2          Sal-es-
# 3          Sal-es-
# 4          Sal-es-
# 5          Sal-es-
# 6          Sal-es-
# 7          Sal-es-
# 8          Sal-es-
# 9      Cus-tom-ers
# 10     Cus-tom-ers
# 11     Cus-tom-ers
# 12     Cus-tom-ers
# 13     Cus-tom-ers
# 14     Cus-tom-ers
# 15     Cus-tom-ers
# 16     Cus-tom-ers
# 17     Cus-tom-ers
# 18     Cus-tom-ers
# 19      Pro-duc-ts
# 20      Pro-duc-ts
# 21      Pro-duc-ts
# 22      Pro-duc-ts
# 23      Pro-duc-ts
# 24      Pro-duc-ts
# 25      Pro-duc-ts
# 26      Pro-duc-ts
# 27      Pro-duc-ts
# 28      Pro-duc-ts
# 29        Sto-res-
# 30        Sto-res-
# 31        Sto-res-
# 32        Sto-res-
# 33        Sto-res-
# 34    Exc-han-ge R
# 35    Exc-han-ge R
# 36    Exc-han-ge R
# Name: Table, dtype: object

# %%
#df_customers["Table"] = df_customers["Table"].str.replace('[^a-zA-Z0-9]','')

#df_customers["Table"].apply(lambda x: x[0:3] + '-' + x [3:6] + '-' + x[6:10])

str(df_customers["Table"])
# Out:
# '0              Sales\n1              Sales\n2              Sales\n3              Sales\n4              Sales\n5              Sales\n6              Sales\n7              Sales\n8              Sales\n9          Customers\n10         Customers\n11         Customers\n12         Customers\n13         Customers\n14         Customers\n15         Customers\n16         Customers\n17         Customers\n18         Customers\n19          Products\n20          Products\n21          Products\n22          Products\n23          Products\n24          Products\n25          Products\n26          Products\n27          Products\n28          Products\n29            Stores\n30            Stores\n31            Stores\n32            Stores\n33            Stores\n34    Exchange Rates\n35    Exchange Rates\n36    Exchange Rates\nName: Table, dtype: object'

# %%
#df_customers["Table"] = df_customers["Table"].str.replace('[^a-zA-Z0-9]','')

#df_customers["Table"].apply(lambda x: x[0:3] + '-' + x [3:6] + '-' + x[6:10])

df_customers["Table"].apply(lambda x: str(x))
# Out:
# 0              Sales
# 1              Sales
# 2              Sales
# 3              Sales
# 4              Sales
# 5              Sales
# 6              Sales
# 7              Sales
# 8              Sales
# 9          Customers
# 10         Customers
# 11         Customers
# 12         Customers
# 13         Customers
# 14         Customers
# 15         Customers
# 16         Customers
# 17         Customers
# 18         Customers
# 19          Products
# 20          Products
# 21          Products
# 22          Products
# 23          Products
# 24          Products
# 25          Products
# 26          Products
# 27          Products
# 28          Products
# 29            Stores
# 30            Stores
# 31            Stores
# 32            Stores
# 33            Stores
# 34    Exchange Rates
# 35    Exchange Rates
# 36    Exchange Rates
# Name: Table, dtype: object

# %%
#df_customers["Table"] = df_customers["Table"].str.replace('[^a-zA-Z0-9]','')

#df_customers["Table"].apply(lambda x: x[0:3] + '-' + x [3:6] + '-' + x[6:10])

#df_customers["Table"] = df_customers["Table"].apply(lambda x: str(x))

df_customers["Table"].apply(lambda x: x[0:3] + '-' + x [3:6] + '-' + x[6:10])
# Out:
# 0          Sal-es-
# 1          Sal-es-
# 2          Sal-es-
# 3          Sal-es-
# 4          Sal-es-
# 5          Sal-es-
# 6          Sal-es-
# 7          Sal-es-
# 8          Sal-es-
# 9      Cus-tom-ers
# 10     Cus-tom-ers
# 11     Cus-tom-ers
# 12     Cus-tom-ers
# 13     Cus-tom-ers
# 14     Cus-tom-ers
# 15     Cus-tom-ers
# 16     Cus-tom-ers
# 17     Cus-tom-ers
# 18     Cus-tom-ers
# 19      Pro-duc-ts
# 20      Pro-duc-ts
# 21      Pro-duc-ts
# 22      Pro-duc-ts
# 23      Pro-duc-ts
# 24      Pro-duc-ts
# 25      Pro-duc-ts
# 26      Pro-duc-ts
# 27      Pro-duc-ts
# 28      Pro-duc-ts
# 29        Sto-res-
# 30        Sto-res-
# 31        Sto-res-
# 32        Sto-res-
# 33        Sto-res-
# 34    Exc-han-ge R
# 35    Exc-han-ge R
# 36    Exc-han-ge R
# Name: Table, dtype: object

# %%
#df_customers["Table"] = df_customers["Table"].str.replace('[^a-zA-Z0-9]','')

#df_customers["Table"].apply(lambda x: x[0:3] + '-' + x [3:6] + '-' + x[6:10])

#df_customers["Table"] = df_customers["Table"].apply(lambda x: str(x))

df_customers["Table"] = df_customers["Table"].apply(lambda x: x[0:3] + '-' + x [3:6] + '-' + x[6:10])
df_customers
# Out:
#            Table           Field
# 0        Sal-es-    Order Number
# 1        Sal-es-       Line Item
# 2        Sal-es-      Order Date
# 3        Sal-es-   Delivery Date
# 4        Sal-es-     CustomerKey
# 5        Sal-es-        StoreKey
# 6        Sal-es-      ProductKey
# 7        Sal-es-        Quantity
# 8        Sal-es-   Currency Code
# 9    Cus-tom-ers     CustomerKey
# 10   Cus-tom-ers          Gender
# 11   Cus-tom-ers            Name
# 12   Cus-tom-ers            City
# 13   Cus-tom-ers      State Code
# 14   Cus-tom-ers           State
# 15   Cus-tom-ers        Zip Code
# 16   Cus-tom-ers         Country
# 17   Cus-tom-ers       Continent
# 18   Cus-tom-ers        Birthday
# 19    Pro-duc-ts      ProductKey
# 20    Pro-duc-ts    Product Name
# 21    Pro-duc-ts           Brand
# 22    Pro-duc-ts           Color
# 23    Pro-duc-ts   Unit Cost USD
# 24    Pro-duc-ts  Unit Price USD
# 25    Pro-duc-ts  SubcategoryKey
# 26    Pro-duc-ts     Subcategory
# ...

# %%
#df_customers["Table"] = df_customers["Table"].str.replace('[^a-zA-Z0-9]','')

#df_customers["Table"].apply(lambda x: x[0:3] + '-' + x [3:6] + '-' + x[6:10])

#df_customers["Table"] = df_customers["Table"].apply(lambda x: str(x))

df_customers["Table"] = df_customers["Table"].apply(lambda x: x[0:3] + '-' + x [3:6] + '-' + x[6:10])
df_customers["Table"].str.replace('Birthday--','')
# Out:
# 0      Sal---e-s--
# 1      Sal---e-s--
# 2      Sal---e-s--
# 3      Sal---e-s--
# 4      Sal---e-s--
# 5      Sal---e-s--
# 6      Sal---e-s--
# 7      Sal---e-s--
# 8      Sal---e-s--
# 9     Cus---t-o-m-
# 10    Cus---t-o-m-
# 11    Cus---t-o-m-
# 12    Cus---t-o-m-
# 13    Cus---t-o-m-
# 14    Cus---t-o-m-
# 15    Cus---t-o-m-
# 16    Cus---t-o-m-
# 17    Cus---t-o-m-
# 18    Cus---t-o-m-
# 19    Pro---d-u-c-
# 20    Pro---d-u-c-
# 21    Pro---d-u-c-
# 22    Pro---d-u-c-
# 23    Pro---d-u-c-
# 24    Pro---d-u-c-
# 25    Pro---d-u-c-
# 26    Pro---d-u-c-
# 27    Pro---d-u-c-
# 28    Pro---d-u-c-
# 29    Sto---r-e-s-
# 30    Sto---r-e-s-
# 31    Sto---r-e-s-
# 32    Sto---r-e-s-
# 33    Sto---r-e-s-
# 34    Exc---h-a-n-
# 35    Exc---h-a-n-
# 36    Exc---h-a-n-
# Name: Table, dtype: object

# %%
#df_customers["Table"] = df_customers["Table"].str.replace('[^a-zA-Z0-9]','')

#df_customers["Table"].apply(lambda x: x[0:3] + '-' + x [3:6] + '-' + x[6:10])

#df_customers["Table"] = df_customers["Table"].apply(lambda x: str(x))

df_customers["Table"] = df_customers["Table"].apply(lambda x: x[0:3] + '-' + x [3:6] + '-' + x[6:10])
df_customers["Table"] = df_customers["Table"].str.replace('Birthday--','')
df_customers["Order Number"] = df_customers["Order Number"].str.replace('Na--','')
df
# Out:
#              Table           Field  \
# 0            Sales    Order Number
# 1            Sales       Line Item
# 2            Sales      Order Date
# 3            Sales   Delivery Date
# 4            Sales     CustomerKey
# 5            Sales        StoreKey
# 6            Sales      ProductKey
# 7            Sales        Quantity
# 8            Sales   Currency Code
# 9        Customers     CustomerKey
# 10       Customers          Gender
# 11       Customers            Name
# 12       Customers            City
# 13       Customers      State Code
# 14       Customers           State
# 15       Customers        Zip Code
# 16       Customers         Country
# 17       Customers       Continent
# 18       Customers        Birthday
# 19        Products      ProductKey
# 20        Products    Product Name
# 21        Products           Brand
# 22        Products           Color
# 23        Products   Unit Cost USD
# 24        Products  Unit Price USD
# ...

# %% [markdown]
# SPLIT

# %%
df_customers["Table"].str.split(expand=True)
# Out:
#                0
# 0   Sal---------
# 1   Sal---------
# 2   Sal---------
# 3   Sal---------
# 4   Sal---------
# 5   Sal---------
# 6   Sal---------
# 7   Sal---------
# 8   Sal---------
# 9   Cus---------
# 10  Cus---------
# 11  Cus---------
# 12  Cus---------
# 13  Cus---------
# 14  Cus---------
# 15  Cus---------
# 16  Cus---------
# 17  Cus---------
# 18  Cus---------
# 19  Pro---------
# 20  Pro---------
# 21  Pro---------
# 22  Pro---------
# 23  Pro---------
# 24  Pro---------
# 25  Pro---------
# 26  Pro---------
# 27  Pro---------
# 28  Pro---------
# 29  Sto---------
# 30  Sto---------
# 31  Sto---------
# 32  Sto---------
# 33  Sto---------
# 34  Exc---------
# 35  Exc---------
# 36  Exc---------

# %%
# Data merging
merged_data = pd.merge(sales, customers, on='customer_id')
merged_data = pd.merge(merged_data, products, on='product_id')
merged_data = pd.merge(merged_data, stores, on='store_id')
merged_data = pd.merge(merged_data, currency_exchange_rates, on='currency_code')

# %%
import pandas as pd
# Load datasets

df = Data_Dictionary = pd.read_csv(r'C:\Users\Administrator\Downloads\Data_Dictionary.csv', encoding='latin-1')
df
# Out:
#              Table           Field  \
# 0            Sales    Order Number
# 1            Sales       Line Item
# 2            Sales      Order Date
# 3            Sales   Delivery Date
# 4            Sales     CustomerKey
# 5            Sales        StoreKey
# 6            Sales      ProductKey
# 7            Sales        Quantity
# 8            Sales   Currency Code
# 9        Customers     CustomerKey
# 10       Customers          Gender
# 11       Customers            Name
# 12       Customers            City
# 13       Customers      State Code
# 14       Customers           State
# 15       Customers        Zip Code
# 16       Customers         Country
# 17       Customers       Continent
# 18       Customers        Birthday
# 19        Products      ProductKey
# 20        Products    Product Name
# 21        Products           Brand
# 22        Products           Color
# 23        Products   Unit Cost USD
# 24        Products  Unit Price USD
# ...

# %%
import pandas as pd
# Load datasets

df_stores = pd.read_csv(r'C:\Users\Administrator\Desktop\Stores.csv', encoding='latin-1')
df
# Out:
#        CustomerKey  Gender               Name                 City State_Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
import pandas as pd
# Load datasets

df_sales = pd.read_csv(r'C:\Users\Administrator\Desktop\Sales.csv', encoding='latin-1')
df_sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
import pandas as pd
# Load datasets

df_products = pd.read_csv(r'C:\Users\Administrator\Desktop\Products.csv',encoding='latin-1')
df_products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# ...

# %%
import pandas as pd
# Load datasets

df_exc_rates = pd.read_csv(r'C:\Users\Administrator\Downloads\Exchange_Rates.csv', encoding='latin-1')
df_exc_rates
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
# Rename columns to replace spaces with underscores
for df in [df_customers, df_exc_rates, df_products, df_sales, df_stores]:
    df.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)

# %%
# Adjust data types
df_sales['Order_Number'] = df_sales['Order_Number'].astype('int64')
df_sales['Line_Item'] = df_sales['Line_Item'].astype('int8')
df_sales['CustomerKey'] = df_sales['CustomerKey'].astype('int64')
df_sales['StoreKey'] = df_sales['StoreKey'].astype('int8')
df_sales['ProductKey'] = df_sales['ProductKey'].astype('int16')
df_sales['Quantity'] = df_sales['Quantity'].astype('int8')
df_products['SubcategoryKey'] = df_products['SubcategoryKey'].astype('int16')
df_products['CategoryKey'] = df_products['CategoryKey'].astype('int8')
df_products['Unit_Cost_USD'] = df_products['Unit_Cost_USD'].replace('[\$,]', '', regex=True).astype(float)
df_products['Unit_Price_USD'] = df_products['Unit_Price_USD'].replace('[\$,]', '', regex=True).astype(float)
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\$'
# <>:11: SyntaxWarning: invalid escape sequence '\$'
# <>:10: SyntaxWarning: invalid escape sequence '\$'
# <>:11: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_12228\530414614.py:10: SyntaxWarning: invalid escape sequence '\$'
#   df_products['Unit_Cost_USD'] = df_products['Unit_Cost_USD'].replace('[\$,]', '', regex=True).astype(float)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_12228\530414614.py:11: SyntaxWarning: invalid escape sequence '\$'
#   df_products['Unit_Price_USD'] = df_products['Unit_Price_USD'].replace('[\$,]', '', regex=True).astype(float)

# %%
import pandas as pd

# %%
df_sales = pd.read_csv(r"C:\Users\Administrator\Desktop\Sales.csv")
df_sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %% [markdown]
# # read data from the file and handle null values

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Administrator\Desktop\Sales.csv")
df['Line Item'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7], dtype=int64)

# %%
# rename columns name 
df.rename (columns={'Order Number':'order number','Delivery Date':'delivery date'})
# Out:
#        order number  Line Item Order Date delivery date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...
